# %%
# !pip install beautifulsoup4

# %% [raw]
# from bs4 import BeautifulSoup
# import requests

# %%
url = "https://www.linkedin.com/jobs/"

# %%
b = requests.get(url)
b
# Out:
# <Response [200]>

# %%
a=BeautifulSoup(b.text)
type(a)
# Out:
# bs4.BeautifulSoup

# %%
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_homepage-guest-jobs-home" name="pageKey"/>
#   <!-- -->
#   <!-- -->
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.1.1585" data-browser-id="38f4638e-7bbe-463b-812f-5f1f8f017c08" data-call-tree-id="AAYgapoFDiU359nyfiy/Mg==" data-dfp-member-lix-treatment="control" data-disable-jsbeacon-pagekey-suffix="false" data-dna-member-lix-treatment="control" data-enable-page-view-heartbeat-tracking="" data-human-member-lix-treatment="control" data-jet-tags="guest-homepage" data-member-id="0" data-multiproduct-name="homepage-guest-frontend" data-page-instance="urn:li:page:d_homepage-guest-jobs-home;IjFJNK0iQTmM+0D+yZNZNA==" data-service-name="homepage-guest-frontend" id="config"/>
#   <link href="https://www.linkedin.com/jobs" rel="canonical"/>
#   <link href="https://de.linkedin.com/jobs" hreflang="de" rel="alternate"/>
#   <link href="https://ie.linkedin.com/jobs" hreflang="en-IE" rel="alternate"/>
# ...

# %%
a.find('div')
# Out:
# <div class="toasts fixed z-8 babybear:right-4 mamabear:right-4 papabear:min-h-[96px] invisible top:auto bottom-4 left-4 papabear:w-[400px] toasts--bottom" id="toasts" type="bottom">
# <template id="toast-template">
# <div class="toast container-raised flex toast--bottom transition ease-accelerate duration-xxslow hidden last:flex" data-id="toast">
# <div class="toast__message flex flex-1 babybear:items-center mamabear:items-center papabear:items-start py-2 px-1.5" data-id="toast__message" role="alert" tabindex="-1">
# <div class="toast__message-content-container" data-id="toast__message-content-container">
# <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>
# </div>
# </div>
# ...

# %%
a.find('li')
# Out:
# <li class="explore-content__pill">
# <a class="btn-md mb-1.5 mr-[6px] flex items-center w-fit float-left btn-secondary-emphasis" data-tracking-control-name="homepage-jobseeker_explore-content_topic-pill" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/home/">
#
#             See All Topics
#
#         </a>
# </li>

# %%
a.find('a')
# Out:
# <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#       Skip to main content
#     </a>

# %%
a.find('li',{'class':'explore-content_pill'})

# %%
a.find('template')
# Out:
# <template id="toast-template">
# <div class="toast container-raised flex toast--bottom transition ease-accelerate duration-xxslow hidden last:flex" data-id="toast">
# <div class="toast__message flex flex-1 babybear:items-center mamabear:items-center papabear:items-start py-2 px-1.5" data-id="toast__message" role="alert" tabindex="-1">
# <div class="toast__message-content-container" data-id="toast__message-content-container">
# <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>
# </div>
# </div>
# <button aria-label="Close" class="toast__dismiss-btn cursor-pointer babybear:self-center mamabear:self-center papabear:self-start pt-3 pb-2 papabear:py-2 pl-0.5 pr-0" data-id="toast__dismiss-btn">
# <svg class="fill-color-icon" height="24" width="24"><path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path></svg>
# ...

# %%
a.find('button')
# Out:
# <button aria-label="Close" class="toast__dismiss-btn cursor-pointer babybear:self-center mamabear:self-center papabear:self-start pt-3 pb-2 papabear:py-2 pl-0.5 pr-0" data-id="toast__dismiss-btn">
# <svg class="fill-color-icon" height="24" width="24"><path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path></svg>
# </button>

# %%
a.find('span')
# Out:
# <span class="sr-only">LinkedIn</span>

# %%
a.find('p')
# Out:
# <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>

# %%
a.find('path')
# Out:
# <path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path>

# %%
a.find('svg')
# Out:
# <svg class="fill-color-icon" height="24" width="24"><path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path></svg>

# %%
a.find('svg').text
# Out:
# ''

# %%
a.find('p').text
# Out:
# ''

# %%
a.find('icon')
# Out:
# <icon class="text-color-icon-caution toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/u6kgm8vi5s4rhtbgmjlphlp6"></icon>

# %%
a.find('a')
# Out:
# <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#       Skip to main content
#     </a>

# %%
a.find('ul')
# Out:
# <ul class="show-more-less__list show-more-less__list--no-hidden-elems" data-impression-id="homepage-jobseeker_explore-content_pill-list-module_etta-show-more-less_show-more-less">
# <li class="explore-content__pill">
# <a class="btn-md mb-1.5 mr-[6px] flex items-center w-fit float-left btn-secondary-emphasis" data-tracking-control-name="homepage-jobseeker_explore-content_topic-pill" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/home/">
#
#             See All Topics
#
#         </a>
# </li>
# <li class="explore-content__pill">
# <a class="btn-md mb-1.5 mr-[6px] flex items-center w-fit float-left btn-secondary" data-tracking-control-name="homepage-jobseeker_explore-content_topic-pill" data-tracking-will-navigate="" href="https://www.linkedin.com/pulse/topics/workplace-c9/">
#
#               Workplace
#
#         </a>
# </li>
# <li class="explore-content__pill">
# ...

# %%
a.find('section')
# Out:
# <section class="section min-h-[560px] flex-nowrap pt-[40px] babybear:flex-col babybear:min-h-[0] babybear:px-mobile-container-padding babybear:pt-[24px]" data-test-id="hero">
# <div class="self-start relative flex-shrink-0 w-[55%] pr-[42px] babybear:w-full babybear:pr-[0px]" data-test-id="hero__content">
# <h1 class="font-sans babybear:pb-[24px] font-regular leading-regular text-display-xl text-smoke-70 babybear:text-display-md babybear:text-center" data-test-id="hero__headline">
#           Millions of jobs and people hiring
#         </h1>
# <!-- -->
# <div class="hero-cta-form">
# <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
# <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
# <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
# <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
# ...

# %%
a.find('input')
# Out:
# <input name="loginCsrfParam" type="hidden" value="38f4638e-7bbe-463b-812f-5f1f8f017c08"/>

# %%
a.find('label')
# Out:
# <label class="input-label mb-1" for="session_key">
#           Email or phone
#         </label>

# %%
a.find('form')
# Out:
# <form action="https://www.linkedin.com/uas/login-submit" class="google-auth" method="post">
# <input name="loginCsrfParam" type="hidden" value="38f4638e-7bbe-463b-812f-5f1f8f017c08"/>
# <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs"/>
# <input name="trk" type="hidden" value="homepage-jobseeker_google-one-tap-submit"/>
# <code id="termsAndConditionsRendered" style="display: none"><!--true--></code>
# <div class="google-one-tap__module hidden fixed flex flex-col items-center top-[20px] right-[20px] z-[9999]">
# <div class="relative top-2 bg-color-background-container-tint pl-2 pr-1 pt-2 pb-3 w-[375px] rounded-md shadow-2xl">
# <p class="text-md font-bold text-color-text">
#                 Agree &amp; Join LinkedIn
#               </p>
# <p class="linkedin-tc__text text-color-text-low-emphasis text-xs pb-2 !text-sm !text-color-text" data-impression-id="homepage-jobseeker_one-tap-skip-tc-text">
# ...

# %%
a.find('h1')
# Out:
# <h1 class="font-sans babybear:pb-[24px] font-regular leading-regular text-display-xl text-smoke-70 babybear:text-display-md babybear:text-center" data-test-id="hero__headline">
#           Millions of jobs and people hiring
#         </h1>

# %%
a.find('code')
# Out:
# <code id="termsAndConditionsRendered" style="display: none"><!--true--></code>

# %%
a.find('section')
# Out:
# <section class="section min-h-[560px] flex-nowrap pt-[40px] babybear:flex-col babybear:min-h-[0] babybear:px-mobile-container-padding babybear:pt-[24px]" data-test-id="hero">
# <div class="self-start relative flex-shrink-0 w-[55%] pr-[42px] babybear:w-full babybear:pr-[0px]" data-test-id="hero__content">
# <h1 class="font-sans babybear:pb-[24px] font-regular leading-regular text-display-xl text-smoke-70 babybear:text-display-md babybear:text-center" data-test-id="hero__headline">
#           Millions of jobs and people hiring
#         </h1>
# <!-- -->
# <div class="hero-cta-form">
# <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
# <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
# <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
# <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
# ...

# %%
a.find('span')
# Out:
# <span class="sr-only">LinkedIn</span>

# %%
a.find('footer')
# Out:
# <footer class="li-footer bg-transparent w-full">
# <ul class="li-footer__list flex flex-wrap flex-row items-start justify-start w-full h-auto min-h-[50px] my-[0px] mx-auto py-3 px-2 papabear:w-[1128px] papabear:p-0">
# <li class="li-footer__item font-sans text-xs text-color-text-low-emphasis flex flex-shrink-0 justify-start p-1 relative w-50% papabear:justify-center papabear:w-auto">
# <span class="sr-only">LinkedIn</span>
# <icon class="li-footer__copy-logo text-color-logo-brand-alt inline-block self-center h-[14px] w-[56px] mr-1" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/e12h2cd8ac580qen9qdd0qks8"></icon>
# <span class="li-footer__copy-text flex items-center">© 2024</span>
# </li>
# <li class="li-footer__item font-sans text-xs text-color-text-low-emphasis flex flex-shrink-0 justify-start p-1 relative w-50% papabear:justify-center papabear:w-auto">
# ...

# %%
a.find('icon')
# Out:
# <icon class="text-color-icon-caution toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/aero-v1/sc/h/u6kgm8vi5s4rhtbgmjlphlp6"></icon>

# %%
a.find('h2')
# Out:
# <h2 class="header">
#           Explore topics you are interested in
#         </h2>

# %%
a.find('h3')
# Out:
# <h3 class="body mb-[40px] babybear:mb-[24px]">
#             Anyone looking to navigate their professional life.
#           </h3>

# %%
a.find('body')
# Out:
# <body dir="ltr">
# <!-- -->
# <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#       Skip to main content
#     </a>
# <!-- -->
# <div class="toasts fixed z-8 babybear:right-4 mamabear:right-4 papabear:min-h-[96px] invisible top:auto bottom-4 left-4 papabear:w-[400px] toasts--bottom" id="toasts" type="bottom">
# <template id="toast-template">
# <div class="toast container-raised flex toast--bottom transition ease-accelerate duration-xxslow hidden last:flex" data-id="toast">
# <div class="toast__message flex flex-1 babybear:items-center mamabear:items-center papabear:items-start py-2 px-1.5" data-id="toast__message" role="alert" tabindex="-1">
# <div class="toast__message-content-container" data-id="toast__message-content-container">
# <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>
# </div>
# </div>
# ...

# %%
a.find('html')
# Out:
# <html lang="en">
# <head>
# <meta content="d_homepage-guest-jobs-home" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# <meta data-app-version="2.1.1585" data-browser-id="38f4638e-7bbe-463b-812f-5f1f8f017c08" data-call-tree-id="AAYgapoFDiU359nyfiy/Mg==" data-dfp-member-lix-treatment="control" data-disable-jsbeacon-pagekey-suffix="false" data-dna-member-lix-treatment="control" data-enable-page-view-heartbeat-tracking="" data-human-member-lix-treatment="control" data-jet-tags="guest-homepage" data-member-id="0" data-multiproduct-name="homepage-guest-frontend" data-page-instance="urn:li:page:d_homepage-guest-jobs-home;IjFJNK0iQTmM+0D+yZNZNA==" data-service-name="homepage-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/jobs" rel="canonical"/>
# <link href="https://de.linkedin.com/jobs" hreflang="de" rel="alternate"/>
# <link href="https://ie.linkedin.com/jobs" hreflang="en-IE" rel="alternate"/>
# ...

# %%
a.find('code')
# Out:
# <code id="termsAndConditionsRendered" style="display: none"><!--true--></code>

# %%
a.find('script')
# Out:
# <script>
#           function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
#           window.lazyloader = getDfd();
#           window.tracking = getDfd();
#           window.impressionTracking = getDfd();
#           window.ingraphTracking = getDfd();
#           window.appDetection = getDfd();
#           window.pemTracking = getDfd();
#         </script>

# %%
a.find('head')
# Out:
# <head>
# <meta content="d_homepage-guest-jobs-home" name="pageKey"/>
# <!-- --><!-- --> <meta content="en_US" name="locale"/>
# <meta data-app-version="2.1.1585" data-browser-id="38f4638e-7bbe-463b-812f-5f1f8f017c08" data-call-tree-id="AAYgapoFDiU359nyfiy/Mg==" data-dfp-member-lix-treatment="control" data-disable-jsbeacon-pagekey-suffix="false" data-dna-member-lix-treatment="control" data-enable-page-view-heartbeat-tracking="" data-human-member-lix-treatment="control" data-jet-tags="guest-homepage" data-member-id="0" data-multiproduct-name="homepage-guest-frontend" data-page-instance="urn:li:page:d_homepage-guest-jobs-home;IjFJNK0iQTmM+0D+yZNZNA==" data-service-name="homepage-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/jobs" rel="canonical"/>
# <link href="https://de.linkedin.com/jobs" hreflang="de" rel="alternate"/>
# <link href="https://ie.linkedin.com/jobs" hreflang="en-IE" rel="alternate"/>
# ...

# %%
a.find('title')
# Out:
# <title>LinkedIn Job Search: Find US Jobs, Internships, Jobs Near Me</title>

# %%
a.find('meta')
# Out:
# <meta content="d_homepage-guest-jobs-home" name="pageKey"/>

# %%
a.find('link')
# Out:
# <link href="https://www.linkedin.com/jobs" rel="canonical"/>
